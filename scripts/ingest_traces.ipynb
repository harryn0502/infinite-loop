# %%
from ingestion import ingest_file
json_path = "../raw_data/langsmith_traces.json"
# !python create_db.py
# !python ingestion.py {json_path}
db_path = '../db_as_files/agent_debug_db.sqlite'
# Out:
# Schema ensured at: ../db_as_files/agent_debug_db.sqlite

# %% [markdown]
# # look at the ingested

# %%
import sqlite3, os
import pandas as pd
conn = sqlite3.connect(db_path)
cur = conn.cursor()
# table names
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
# Out:
#          name
# 0  agent_runs
# 1       steps

# %%
# pd.read_sql_query("SELECT * FROM agent_runs LIMIT 10", conn)

agent_runs = pd.read_sql_query("SELECT * FROM agent_runs LIMIT 10", conn)
steps = pd.read_sql_query("SELECT * FROM steps", conn)
# combine and query 
# 
agent_runs
# Out:
#                                  run_id                  start_time  \
# 0  18d2cd15-a95d-4584-b178-2539673a2b83  2025-11-15 15:04:57.044280
# 1  05295414-6fd6-4613-a5f9-6a9e8abd38f8  2025-11-15 15:04:15.363789
# 2  cbec1faf-d291-4302-b185-2527560622df  2025-11-15 15:01:45.551263
# 3  019a87f2-22c5-7591-aa04-2b98e86f7ac7  2025-11-15 14:36:25.278269
# 4  019a87e6-58b9-770c-b0ee-cab50488b929  2025-11-15 14:23:32.246559
# 5  019a87e5-e024-73b1-8795-4a3f1d02870a  2025-11-15 14:23:01.161461
# 6  019a87db-255b-707e-8166-ac66400ae63d  2025-11-15 14:11:18.193327
#
#                      end_time   status  \
# 0  2025-11-15 15:05:26.752734  success
# 1  2025-11-15 15:04:16.785803    error
# 2  2025-11-15 15:01:56.399781  success
# 3  2025-11-15 14:39:48.311991    error
# 4  2025-11-15 14:24:30.471913    error
# 5  2025-11-15 14:23:05.916849    error
# 6  2025-11-15 14:11:24.187372    error
#
#                                                error user_id  \
# 0                                               None    None
# 1  KeyboardInterrupt()Traceback (most recent call...    None
# 2                                               None    None
# 3  BadRequestError('Error code: 400 - {\'error\':...    None
# 4  MissingAPIKeyError('No API key provided. Pleas...    None
# 5  AuthenticationError('Error code: 401 - {\'erro...    None
# 6  AuthenticationError('Error code: 401 - {\'erro...    None
#
#                              session_id thread_id  \
# 0  b6fc2425-8a41-441e-bb22-865e99af5de7      None
# 1  b6fc2425-8a41-441e-bb22-865e99af5de7      None
# 2  b6fc2425-8a41-441e-bb22-865e99af5de7      None
# 3  b6fc2425-8a41-441e-bb22-865e99af5de7      None
# 4  b6fc2425-8a41-441e-bb22-865e99af5de7      None
# 5  b6fc2425-8a41-441e-bb22-865e99af5de7      None
# 6  b6fc2425-8a41-441e-bb22-865e99af5de7      None
#
#                                       input_messages  \
# 0  [[{"id": ["langchain", "schema", "messages", "...
# 1  [[{"id": ["langchain", "schema", "messages", "...
# 2  [[{"id": ["langchain", "schema", "messages", "...
# 3  [[{"id": ["langchain", "schema", "messages", "...
# 4  [[{"id": ["langchain", "schema", "messages", "...
# 5  [[{"id": ["langchain", "schema", "messages", "...
# 6  [[{"id": ["langchain", "schema", "messages", "...
#
#                                      output_messages model_name tags  \
# 0  [[{"text": "Based on the search results, I can...       None   []
# 1                                               [[]]       None   []
# 2  [[{"generation_info": null, "message": {"id": ...       None   []
# 3  [[{"generation_info": {"finish_reason": "stop"...       None   []
# 4  [[{"generation_info": {"finish_reason": "stop"...       None   []
# 5  [[{"generation_info": null, "message": {"id": ...       None   []
# 6  [[{"generation_info": null, "message": {"id": ...       None   []
#
#                                   langgraph_metadata  \
# 0  {"LANGSMITH_ENDPOINT": "https://api.smith.lang...
# 1  {"LANGSMITH_ENDPOINT": "https://api.smith.lang...
# 2  {"LANGSMITH_ENDPOINT": "https://api.smith.lang...
# 3  {"LANGGRAPH_API_URL": "http://127.0.0.1:2024",...
# 4  {"LANGGRAPH_API_URL": "http://127.0.0.1:2024",...
# 5  {"LANGGRAPH_API_URL": "http://127.0.0.1:2024",...
# 6  {"LANGGRAPH_API_URL": "http://127.0.0.1:2024",...
#
#                                              runtime  total_tokens  total_cost
# 0  {"langchain_core_version": "1.0.5", "langchain...             0    0.000000
# 1  {"langchain_core_version": "1.0.5", "langchain...             0    0.000000
# 2  {"langchain_core_version": "1.0.5", "langchain...             0    0.000000
# 3  {"langchain_core_version": "1.0.5", "langchain...        408287    1.051558
# 4  {"langchain_core_version": "1.0.5", "langchain...         95854    0.235820
# 5  {"langchain_core_version": "1.0.5", "langchain...             0    0.000000
# 6  {"langchain_core_version": "1.0.5", "langchain...             0    0.000000

# %%
steps.head(5).T
# Out:
#                                                                          0  \
# step_id                               18d2cd15-a95d-4584-b178-2539673a2b83
# run_id                                18d2cd15-a95d-4584-b178-2539673a2b83
# step_index                                                               0
# is_llm_call                                                              0
# is_tool_call                                                             0
# is_chain_call                                                            1
# prompt_text                                                           None
# llm_output_text                                                       None
# llm_input_tokens                                                       0.0
# llm_output_tokens                                                      0.0
# llm_total_tokens                                                       0.0
# llm_prompt_cost                                                        NaN
# llm_completion_cost                                                    NaN
# llm_total_cost                                                         NaN
# finish_reason                                                         None
# model_name                                                            None
# model_provider                                                        None
# tool_call_requests                                                    None
# tool_name                                                             None
# tool_args                                                             None
# tool_status                                                           None
# tool_response                                                         None
# tool_message_content                                                  None
# tool_cost                                                             None
# tool_latency_ms                                                        NaN
# chain_name                                                     ReAct Agent
# chain_status                                                       success
# chain_input_messages              [["user", "What is quantum computing?"]]
# chain_output_messages    [{"content": "What is quantum computing?", "ad...
# chain_prompt_tokens                                                    0.0
# chain_completion_tokens                                                0.0
# chain_total_tokens                                                     0.0
# chain_prompt_cost                                                      NaN
# chain_completion_cost                                                  NaN
# chain_total_cost                                                       NaN
# previous_step_id                                                      None
#
#                                                                          1  \
# step_id                               213862dc-cd1e-41af-8ead-4bf70b4507b7
# run_id                                18d2cd15-a95d-4584-b178-2539673a2b83
# step_index                                                               1
# is_llm_call                                                              0
# is_tool_call                                                             0
# is_chain_call                                                            1
# prompt_text                                                           None
# llm_output_text                                                       None
# llm_input_tokens                                                       0.0
# llm_output_tokens                                                      0.0
# llm_total_tokens                                                       0.0
# llm_prompt_cost                                                        NaN
# llm_completion_cost                                                    NaN
# llm_total_cost                                                         NaN
# finish_reason                                                         None
# model_name                                                            None
# model_provider                                                        None
# tool_call_requests                                                    None
# tool_name                                                             None
# tool_args                                                             None
# tool_status                                                           None
# tool_response                                                         None
# tool_message_content                                                  None
# tool_cost                                                             None
# tool_latency_ms                                                        NaN
# chain_name                                                      call_model
# chain_status                                                       success
# chain_input_messages                                                  None
# chain_output_messages    [{"additional_kwargs": {}, "content": "", "id"...
# chain_prompt_tokens                                                    0.0
# chain_completion_tokens                                                0.0
# chain_total_tokens                                                     0.0
# chain_prompt_cost                                                      NaN
# chain_completion_cost                                                  NaN
# chain_total_cost                                                       NaN
# previous_step_id                      18d2cd15-a95d-4584-b178-2539673a2b83
#
#                                                                          2  \
# step_id                               1289ea11-818d-4e73-99c4-78076a78e8b2
# run_id                                18d2cd15-a95d-4584-b178-2539673a2b83
# step_index                                                               2
# is_llm_call                                                              1
# is_tool_call                                                             0
# is_chain_call                                                            0
# prompt_text                                                           None
# llm_output_text
# llm_input_tokens                                                       0.0
# llm_output_tokens                                                      0.0
# llm_total_tokens                                                       0.0
# llm_prompt_cost                                                        NaN
# llm_completion_cost                                                    NaN
# llm_total_cost                                                         NaN
# finish_reason                                                         None
# model_name                    us.anthropic.claude-3-5-sonnet-20241022-v2:0
# model_provider                                           holisticaibedrock
# tool_call_requests       [{"args": {"fast_mode": true, "max_num_results...
# tool_name                                                             None
# tool_args                                                             None
# tool_status                                                           None
# tool_response                                                         None
# tool_message_content                                                  None
# tool_cost                                                             None
# tool_latency_ms                                                        NaN
# chain_name                                                            None
# chain_status                                                          None
# chain_input_messages                                                  None
# chain_output_messages                                                 None
# chain_prompt_tokens                                                    NaN
# chain_completion_tokens                                                NaN
# chain_total_tokens                                                     NaN
# chain_prompt_cost                                                      NaN
# chain_completion_cost                                                  NaN
# chain_total_cost                                                       NaN
# previous_step_id                      213862dc-cd1e-41af-8ead-4bf70b4507b7
#
#                                                             3  \
# step_id                  49c7806a-5fce-4dce-a2b1-5cae9a2ded0d
# run_id                   18d2cd15-a95d-4584-b178-2539673a2b83
# step_index                                                  3
# is_llm_call                                                 0
# is_tool_call                                                0
# is_chain_call                                               1
# prompt_text                                              None
# llm_output_text                                          None
# llm_input_tokens                                          0.0
# llm_output_tokens                                         0.0
# llm_total_tokens                                          0.0
# llm_prompt_cost                                           NaN
# llm_completion_cost                                       NaN
# llm_total_cost                                            NaN
# finish_reason                                            None
# model_name                                               None
# model_provider                                           None
# tool_call_requests                                       None
# tool_name                                                None
# tool_args                                                None
# tool_status                                              None
# tool_response                                            None
# tool_message_content                                     None
# tool_cost                                                None
# tool_latency_ms                                           NaN
# chain_name                                       route_simple
# chain_status                                          success
# chain_input_messages                                     None
# chain_output_messages                                    None
# chain_prompt_tokens                                       0.0
# chain_completion_tokens                                   0.0
# chain_total_tokens                                        0.0
# chain_prompt_cost                                         NaN
# chain_completion_cost                                     NaN
# chain_total_cost                                          NaN
# previous_step_id         1289ea11-818d-4e73-99c4-78076a78e8b2
#
#                                                                          4
# step_id                               d93ec5da-48c3-4a5c-b9e3-3d6cf67d2e48
# run_id                                18d2cd15-a95d-4584-b178-2539673a2b83
# step_index                                                               4
# is_llm_call                                                              0
# is_tool_call                                                             0
# is_chain_call                                                            1
# prompt_text                                                           None
# llm_output_text                                                       None
# llm_input_tokens                                                       0.0
# llm_output_tokens                                                      0.0
# llm_total_tokens                                                       0.0
# llm_prompt_cost                                                        NaN
# llm_completion_cost                                                    NaN
# llm_total_cost                                                         NaN
# finish_reason                                                         None
# model_name                                                            None
# model_provider                                                        None
# tool_call_requests                                                    None
# tool_name                                                             None
# tool_args                                                             None
# tool_status                                                           None
# tool_response                                                         None
# tool_message_content                                                  None
# tool_cost                                                             None
# tool_latency_ms                                                        NaN
# chain_name                                                           tools
# chain_status                                                       success
# chain_input_messages                                                  None
# chain_output_messages    [{"additional_kwargs": {}, "content": "{\n  \"...
# chain_prompt_tokens                                                    0.0
# chain_completion_tokens                                                0.0
# chain_total_tokens                                                     0.0
# chain_prompt_cost                                                      NaN
# chain_completion_cost                                                  NaN
# chain_total_cost                                                       NaN
# previous_step_id                      49c7806a-5fce-4dce-a2b1-5cae9a2ded0d
