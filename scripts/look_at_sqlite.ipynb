# %%
db_path = '../db_as_files/agent_debug_db.sqlite'

# %%
# table names
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
# Out:
#          name
# 0  agent_runs
# 1   llm_calls
# 2  tool_calls

# %%
import sqlite3, os
import pandas as pd
conn = sqlite3.connect(db_path)
cur = conn.cursor()

pd.read_sql_query("SELECT * FROM agent_runs LIMIT 10", conn)

agent_runs = pd.read_sql_query("SELECT * FROM agent_runs LIMIT 10", conn)
llm_calls = pd.read_sql_query("SELECT * FROM llm_calls LIMIT 10", conn)
tool_calls = pd.read_sql_query("SELECT * FROM tool_calls LIMIT 10", conn)
print(agent_runs, llm_calls, tool_calls)
# Out:
#     run_id           start_time             end_time user_id session_id  \
# 0  run_001  2025-01-01T10:00:00  2025-01-01T10:00:05   userA      sess1
# 1  run_002  2025-01-01T11:00:00  2025-01-01T11:00:08   userB      sess1
# 2  run_003  2025-01-01T12:00:00  2025-01-01T12:00:15   userA      sess2
#
#   agent_version prompt_template_version model_name      input_text  \
# 0            v1                      p1    gpt-4.1     What is AI?
# 1            v1                      p1    gpt-4.1  Tell me a joke
# 2            v1                      p2    gpt-4.1  Search weather
#
#         final_output  error_flag  error_type  total_cost  total_tokens  \
# 0     AI explanation           0        None        0.02           120
# 1  Here is a joke...           0        None        0.03           140
# 2     Weather result           1  tool_error        0.05           210
#
#        extra_metadata
# 0  {"source": "test"}
# 1  {"source": "test"}
# 2  {"source": "test"}     llm_call_id   run_id  step_index model_name    prompt_text  \
# 0     llm_001  run_001           0    gpt-4.1     Explain AI
# 1     llm_002  run_002           0    gpt-4.1      Tell joke
# 2     llm_003  run_003           0    gpt-4.1  Fetch weather
#
#   prompt_diff_from_previous  temperature  top_p stop_tokens        llm_output  \
# 0                                    0.2    1.0        None         AI is ...
# 1                                    0.8    0.9        None  Here's a joke...
# 2                                    0.2    1.0        None      Searching...
#
#    llm_output_tokens  latency_ms streaming_trace hidden_state_hash  \
# 0                 80         200            None             hashA
# 1                 85         250            None             hashB
# 2                 90         300            None             hashC
#
#    error_flag error_type metadata
# 0           0       None       {}
# 1           0       None       {}
# 2           0       None       {}     tool_call_id   run_id llm_call_id  step_index    tool_name  \
# 0     tool_001  run_003     llm_003           1  weather_api
#
#              tool_input tool_output  tool_error_flag tool_error_type  \
# 0  {location: 'London'}   {temp:10}                1   network_error
#
#    execution_latency_ms streaming_logs retrieved_docs doc_similarity_scores  \
# 0                   500           None           None                  None
#
#   intermediate_state  cost_estimate metadata
# 0               None            0.0       {}

# %%
cur
